# %%
import numpy as np
import os

from utils import set_params
from utils import load_pickle, extract_used_data
from utils import mergeAB, align_track, z_score_on
from utils import plot3d_lines_to_html
from utils import pca_fit
from utils import JPCA

from utils.config import Params

# %%
def jpca_on(data: dict, params: Params, ana_tt: list[str], ana_bt: list[str]):
    
    blocks = []
    for index in params.ana_index_grid(ana_tt, ana_bt):
        if data["aligned_firing"][index] is not None:
            blocks.append(data["aligned_firing"][index])

    if len(blocks) == 0:
        raise ValueError('No data to jpca')

    # fr_sum: [num_neurons, (len_track * num_types)]
    fr_sum = np.hstack(blocks)
    
    pcs, denoise, mu = pca_fit(fr_sum.T, params.pca_n_components)

    P = pcs[:, :params.pca_n_components]         # [n_units, k]
    fr_sum_pca = (fr_sum.T - mu) @ P             # [n_samples, k]

    jpca = JPCA(mean_center=False)
    jpca.fit(fr_sum_pca)
    
    colors = [
        [0.20, 0.20, 0.20],
        [0.99, 0.22, 0.24],
        [0.99, 0.55, 0.16],
        [0.80, 0.12, 0.46],
        [0.20, 0.45, 0.85],
        [0.00, 0.62, 0.45],
        [0.53, 0.36, 0.78],
    ]

    xlines, ylines, zlines = [], [], []
    lineLabels, lineColors = [], []
    
    for index in params.ana_index_grid(ana_tt, ana_bt):
        
        fr = data["aligned_firing"][index]
        if fr is None:
            continue
    
        fr = (fr.T - mu) @ P
        
        vecs = jpca.transform(fr, n_planes=2)

        xline = vecs[:,0]
        yline = vecs[:,1]
        zline = vecs[:,2]
        
        xlines.append(xline)
        ylines.append(yline)
        zlines.append(zline)
        
        row, col = index
        
        lineLabels.append(f"{params.tt[row]} {params.bt[col]}")
        
        if "position" in params.tt[row]:
            color = "#ea8428"
        elif "pattern" in params.tt[row]:
            color = "#288eea"
        else:
            color = "#808080"
        # color = colors[row]
        lineColors.append(color)


    segment_colors = []
    zones = data["aligned_zones_id"]
    for i in range(len(zones)):
        start = zones[i][0]
        end = zones[i][1]
        if i == 0:
            color = "#1f77b4"
        elif i == 2:
            color = "#ff7f0e"
        elif i == 4:
            color = "#d62728"
        else:
            color = "#b283ed"
        segment_colors.append((start, end, color))
        
    return xlines, ylines, zlines, lineLabels, lineColors, segment_colors

# %%
# Params set

data_path = "../../data/PFC-HPC/"
sub_dir = "probeB/RE08-1"
results_path = "../../results/"

params = set_params(tt_preset='merge',
                         bt_preset='basic',
                         data_path=data_path,
                         results_path=results_path,
                         pca_n_components=10)

# %%
# data_dict = load_pickle(os.path.join(params.data_path, sub_dir))

# for key, value in data_dict.items():
    
#     data = data_dict[key]
#     data = extract_used_data(data)
#     mergeAB(data)
    
#     align_track(data, params)
#     # z_score_on(data, params, ana_tt=['*'], ana_bt=['*'])
#     # z_score_on(data, params, ana_tt=['couple'], ana_bt=['*'])
#     # z_score_on(data, params, ana_tt=['pattern_*'], ana_bt=['*'])
#     # z_score_on(data, params, ana_tt=['position_*'], ana_bt=['*'])
#     x_lines, y_lines, zlines, line_labels, line_colors, segment_colors= jpca_on(data, params, ana_tt=['*'], ana_bt=['correct'])

#     # plot
#     out_path = os.path.join(params.results_path, sub_dir, f"{key}_jpca_3D.html")
#     axis_labels = dict(xaxis_title="JPCA1", yaxis_title="JPCA2", zaxis_title="JPCA3")
#     fig = plot3d_lines_to_html(x_lines, y_lines, zlines,
#                          line_labels = line_labels,
#                          line_colors = line_colors,
#                          axis_labels = axis_labels,
#                          segment_per_line = segment_colors,
#                          out_html = out_path)
#     fig.show()

# %%
data = load_pickle('../..//data/PFC_NP/flexible_shift/RDP02-PFCsep.pkl')
data = extract_used_data(data)
mergeAB(data)

align_track(data, params)
x_lines, y_lines, zlines, line_labels, line_colors, segment_colors= jpca_on(data, params, ana_tt=['*'], ana_bt=['correct'])

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator, FormatStrFormatter


def plot_jpca_2d_pseudo3d_by_rule(
    xlines,
    ylines,
    line_labels=None,
    line_colors=None,
    segment_colors=None,
    title="jPCA trajectories",
    x_label="jPC1",
    y_label="jPC2",
    figsize=(8.0, 4.0),
    base_width=1,
    segment_width=2,
    base_alpha=0.8,
    segment_alpha=0.98,
    marker_size=50,
    plane_gap=1.6,
    z_scale=0.8,
    box_aspect=(1, 1, 0.65),
    view_elev=22,
    view_azim=-58,
    n_ticks=8,
    tick_fontsize=9,
    label_fontsize=11,
    title_fontsize=13,
    group_title_fontsize=14,
    save_path=None,
):
    """
    Pseudo-3D plot of 2D jPCA trajectories.
    Only uses xlines and ylines.
    Pattern rule and Position rule are plotted separately.
    """

    if line_labels is None:
        line_labels = [f"Line {i+1}" for i in range(len(xlines))]
    if line_colors is None:
        line_colors = ["#808080"] * len(xlines)
    if segment_colors is None:
        segment_colors = []

    pattern_idx = [
        i for i, lab in enumerate(line_labels)
        if "pattern" in lab.lower()
    ][:3]

    position_idx = [
        i for i, lab in enumerate(line_labels)
        if "position" in lab.lower()
    ][:3]

    fig = plt.figure(figsize=figsize)
    ax_pattern = fig.add_subplot(121, projection="3d")
    ax_position = fig.add_subplot(122, projection="3d")

    def _set_clean_axis_style(ax):
        ax.view_init(elev=view_elev, azim=view_azim)

        ax.xaxis.pane.fill = False
        ax.yaxis.pane.fill = False
        ax.zaxis.pane.fill = False

        ax.xaxis.pane.set_edgecolor((1, 1, 1, 0))
        ax.yaxis.pane.set_edgecolor((1, 1, 1, 0))
        ax.zaxis.pane.set_edgecolor((1, 1, 1, 0))

        ax.grid(False)
        try:
            ax.xaxis._axinfo["grid"]["linewidth"] = 0
            ax.yaxis._axinfo["grid"]["linewidth"] = 0
            ax.zaxis._axinfo["grid"]["linewidth"] = 0

            # 三条轴线保留
            ax.xaxis._axinfo["axisline"]["linewidth"] = 0.8
            ax.yaxis._axinfo["axisline"]["linewidth"] = 0.8
            ax.zaxis._axinfo["axisline"]["linewidth"] = 0.8
        except Exception:
            pass

        ax.set_zticks([])

        ax.xaxis.set_major_locator(MaxNLocator(nbins=n_ticks))
        ax.yaxis.set_major_locator(MaxNLocator(nbins=n_ticks))

        ax.xaxis.set_major_formatter(FormatStrFormatter("%.1f"))
        ax.yaxis.set_major_formatter(FormatStrFormatter("%.1f"))

        ax.tick_params(axis="x", labelsize=tick_fontsize, pad=1)
        ax.tick_params(axis="y", labelsize=tick_fontsize, pad=5)
        ax.tick_params(axis="z", length=0, pad=0)

        ax.set_xlabel(x_label, fontsize=label_fontsize, labelpad=2)
        ax.set_ylabel(y_label, fontsize=label_fontsize, labelpad=8)
        ax.set_zlabel("")

    def _plot_group(ax, indices, group_title):
        all_x = []
        all_y = []
        layers = []

        # 先把每一层数据存起来
        for local_i, i in enumerate(indices):
            x = np.asarray(xlines[i], dtype=float)
            y = np.asarray(ylines[i], dtype=float)
            z = np.full_like(x, local_i * plane_gap * z_scale, dtype=float)

            color = line_colors[i]

            layers.append({
                "local_i": local_i,
                "x": x,
                "y": y,
                "z": z,
                "color": color,
            })

            all_x.append(x)
            all_y.append(y)

        draw_order = sorted(layers, key=lambda d: d["local_i"], reverse=True)

        # 1) 先画 base line
        for layer in draw_order:
            x = layer["x"]
            y = layer["y"]
            z = layer["z"]
            color = layer["color"]

            ax.plot(
                x, y, z,
                color=color,
                linewidth=base_width,
                alpha=base_alpha,
                zorder=1,
            )

        for layer in draw_order:
            x = layer["x"]
            y = layer["y"]
            z = layer["z"]

            for s, e, seg_color in segment_colors:
                s = max(0, int(s))
                e = min(len(x), int(e))
                if e <= s:
                    continue

                ax.plot(
                    x[s:e], y[s:e], z[s:e],
                    color=seg_color,
                    linewidth=segment_width,
                    alpha=segment_alpha,
                    solid_capstyle="round",
                    zorder=3,
                )

        for layer in draw_order:
            x = layer["x"]
            y = layer["y"]
            z = layer["z"]
            color = layer["color"]

            ax.scatter(
                x[0], y[0], z[0],
                marker="o",
                s=marker_size,
                color=color,
                edgecolor="white",
                linewidth=0.8,
                zorder=5,
                depthshade=False,
            )

            ax.scatter(
                x[-1], y[-1], z[-1],
                marker="^",
                s=marker_size,
                color=color,
                edgecolor="white",
                linewidth=0.8,
                zorder=5,
                depthshade=False,
            )

        if len(all_x) > 0:
            all_x = np.concatenate(all_x)
            all_y = np.concatenate(all_y)

            xmin, xmax = all_x.min(), all_x.max()
            ymin, ymax = all_y.min(), all_y.max()

            xr = xmax - xmin
            yr = ymax - ymin

            xpad = 0.03 * (xr + 1e-9)
            ypad = 0.03 * (yr + 1e-9)

            ax.set_xlim(xmin - xpad, xmax + xpad)
            ax.set_ylim(ymin - ypad, ymax + ypad)

            zmax = max(0.4, (len(indices) - 1) * plane_gap * z_scale)
            zpad = 0.02 * max(zmax, 1.0)
            ax.set_zlim(-zpad, zmax + zpad)

            try:
                xy_max = max(xr + 2 * xpad, yr + 2 * ypad)

                x_aspect = (xr + 2 * xpad) / xy_max
                y_aspect = (yr + 2 * ypad) / xy_max

                z_aspect = 0.50

                ax.set_box_aspect((x_aspect, y_aspect, z_aspect))
            except Exception:
                pass

        _set_clean_axis_style(ax)

        ax.text2D(
            0.5, 0.90, group_title,
            transform=ax.transAxes,
            ha="center",
            va="bottom",
            fontsize=group_title_fontsize,
        )

    _plot_group(ax_pattern, pattern_idx, "Pattern rule")
    _plot_group(ax_position, position_idx, "Position rule")

    fig.suptitle(title, fontsize=title_fontsize, x=0.52, y=0.90)

    plt.subplots_adjust(
        left=0.02,
        right=0.99,
        bottom=0.05,
        top=0.88,
        wspace=0.02,
    )
    
    if save_path is not None:
        fig.savefig(
            save_path,
            dpi=300,
            bbox_inches="tight",
            transparent=True,
        )

    return fig, (ax_pattern, ax_position)

# %%
fig, axes = plot_jpca_2d_pseudo3d_by_rule(
    x_lines,
    y_lines,
    line_labels=line_labels,
    line_colors=line_colors,
    segment_colors=segment_colors,
    figsize=(8.0, 4.0),
    base_width=1,
    segment_width=2,
    base_alpha=0.8,
    segment_alpha=0.98,
    marker_size=50,
    plane_gap=1.6,
    z_scale=0.8,
    box_aspect=(1, 1, 0.55),
    n_ticks=6,
    title="jPCA trajectories",
)
