# %%
mods = [
    "numpy","scipy","pandas","bottleneck",
    "sklearn","numba","numexpr",
    "umap","pynndescent",
]
for m in mods:
    try:
        __import__(m)
        print("OK", m)
    except Exception as e:
        print("FAIL", m, "->", repr(e))
        raise
# Out:
# OK numpy
# OK scipy
# OK pandas
# OK bottleneck
# OK sklearn
# OK numba
# OK numexpr
# OK umap
# OK pynndescent
